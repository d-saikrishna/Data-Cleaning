# %% [markdown]
# # Standardizing our key columns before merging dataframes
# Many a times we want to merge different data frames. But often, there is a significant challenge when our key columns of different data frames are not standardised. They contain the same elements, but there could be a spelling mistake or leading spaces etc. Let's see two such data frames.

# %%
import pandas as pd

# %% [markdown]
# # APPROACHES:
#
# ## [1. FUZZY MATCH](#Fuzzy)
#
# ## [2. SEQUENCE MATCHER](#Seq)

# %% [markdown]
# ## 1. FUZZY-MATCH <a id="Fuzzy"></a>

# %%
def fuzzy_merge(df_1, df_2, key1, key2, threshold=90, limit=2):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = df_2[key2].tolist()

    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))    
    df_1['matches'] = m

    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2

    return df_1

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
df1 = pd.DataFrame({'Key':['Apple', 'Banana', 'Orange', 'Strawberry'],
                   'Who ate?':['Sai','Kishore','Nanda','Reddy']})
df1
# Out:
#           Key Who ate?
# 0       Apple      Sai
# 1      Banana  Kishore
# 2      Orange    Nanda
# 3  Strawberry    Reddy

# %%
df2 = pd.DataFrame({'Key':['Aple', 'Orag', 'Straw', 'Bannanna'],
                    'Number':[1,2,3,4]})
df2
# Out:
#         Key  Number
# 0      Aple       1
# 1      Orag       2
# 2     Straw       3
# 3  Bannanna       4

# %%
fuzzymatch = fuzzy_merge(df1, df2, 'Key', 'Key', threshold=80,limit=1)
fuzzymatch
# Out:
#           Key Who ate?   matches
# 0       Apple      Sai      Aple
# 1      Banana  Kishore  Bannanna
# 2      Orange    Nanda      Orag
# 3  Strawberry    Reddy     Straw

# %%
df2 = df2.set_index('Key').reindex(list(fuzzymatch['matches'])).reset_index()
df2['Key'] = df1['Key']
df2
# Out:
#           Key  Number
# 0       Apple       1
# 1      Banana       4
# 2      Orange       2
# 3  Strawberry       3

# %%
pd.merge(df1,df2,on='Key').drop('matches',axis=1)
# Out:
#           Key Who ate?  Number
# 0       Apple      Sai       1
# 1      Banana  Kishore       4
# 2      Orange    Nanda       2
# 3  Strawberry    Reddy       3

# %% [markdown]
# ## SEQUENCE MATCHER <a id="Seq"></a>

# %%
import pandas as pd

# %%
# Dataset-1: Hospital beds in India
beds = pd.read_csv('/content/Govt_HospitalBedsInIndia.csv')
beds.head()
# Out:
#              State/UT  ...  Reference Period
# 0      Andhra Pradesh  ...        01.01.2017
# 1  Arunachal Pradesh*  ...        31.12.2018
# 2             Assam *  ...        31.12.2017
# 3               Bihar  ...        31.12.2018
# 4        Chhattisgarh  ...        01.01.2016
#
# [5 rows x 8 columns]

# %%
# Dataset-2: Population in various states
population = pd.read_csv('/content/Population.csv')
population.head()
# Out:
#          State/UT Population (2018)
# 0   Uttar Pradesh       228,959,599
# 1     Maharashtra       120,837,347
# 2           Bihar       119,461,013
# 3     West Bengal        97,694,960
# 4  Madhya Pradesh        82,342,793

# %% [markdown]
# You may want to merge both data sets to know per-capita availability of hospital beds in each state. But merging will not work as the state names are not standardised.

# %%
percapita_beds = pd.merge(beds, population, on ='State/UT',how='inner')
percapita_beds
# Out:
#            State/UT  ...  Population (2018)
# 0    Andhra Pradesh  ...         52,883,163
# 1             Bihar  ...        119,461,013
# 2      Chhattisgarh  ...         28,566,990
# 3           Gujarat  ...         63,907,200
# 4   Jammu & Kashmir  ...         13,635,010
# 5         Jharkhand  ...         37,329,128
# 6            Kerala  ...         35,330,888
# 7    Madhya Pradesh  ...         82,342,793
# 8       Maharashtra  ...        120,837,347
# 9           Manipur  ...          3,008,546
# 10         Nagaland  ...          2,189,297
# 11      Uttarakhand  ...         11,090,425
# 12      West Bengal  ...         97,694,960
# 13       Chandigarh  ...          1,126,705
# 14      Daman & Diu  ...            220,084
# 15            Delhi  ...         18,345,784
# 16      Lakshadweep  ...             71,218
# 17       Puducherry  ...          1,375,592
#
# [18 rows x 9 columns]

# %% [markdown]
# Only 18 entries out of 36 could be part of the join. Because other 18 entries have minor differences within them.

# %%
sorted(list(beds['State/UT']))
# Out:
# ['A&N Island',
#  'Andhra Pradesh',
#  'Arunachal Pradesh*',
#  'Assam *',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'D&N Haveli*',
#  'Daman & Diu',
#  'Delhi',
#  'Goa*',
#  'Gujarat',
#  'Haryana*',
#  'Himachal Pradesh*',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka*',
#  'Kerala',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya*',
#  'Mizoram*',
#  'Nagaland',
#  'Odisha*',
#  'Puducherry',
#  'Punjab*',
#  'Rajasthan *',
#  'Sikkim*',
#  'Tamil Nadu*',
#  'Telangana*',
#  'Tripura*',
#  'Uttar Pradesh*',
#  'Uttarakhand',
#  'West Bengal']

# %%
sorted(list(population['State/UT']))
# Out:
# ['A.& N.Islands',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'D.& N.Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal']

# %% [markdown]
# You can observe that many states/UTs are represented differently.
# "Andaman and Nicobar Islands" in one dataframe ; "A&N Island" in another.
#
# Such issues affect our JOINS. If it is for single use we can simply rename the fields bothering our join. But when we have to merge multiple data frames, you require a **standard key column**

# %% [markdown]
# In our case let's fix that the state names in population dataframe as the standard format. In any dataframes we work in future, the state names in those data frames should be the same as the standard format. Only then JOINs can be done easily.

# %% [markdown]
# ## LOGIC:
# 1. Select a state name and compare it with all the standard state names. After each comparison, there should be a metric to measure the matching between both strings.
# 2. We will select the standard state name that has maximum matching with the selected state.
# 3. Rename the state name with standard name.
# 4. Repeat with other states.

# %%
#Sequence Matcher helps us get the metric that measures how two strings are matching
from difflib import SequenceMatcher

#We will write a function that gives us matching score between two strings a and b. Higher the score,better the match
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
similar('Apple',"Apple")
# Out:
# 1.0

# %%
similar('Apple',"Aple")
# Out:
# 0.8888888888888888

# %%
similar('Apple',"Pineapple")
# Out:
# 0.5714285714285714

# %%
similar('Apple',"Mango")
# Out:
# 0.0

# %%
#Fix the standard state names
standard_state_names = list(population['State/UT'])

#Empty list to store the standard names of each state in our dataframe
standard_names = []

for state in list(beds['State/UT']):
  # Empty list to store all scores
  matches = []

  #Position of selected state in the list. We need it because, we will have to rename it with stadard value later.
  statepos = list(beds['State/UT']).index(state)

  for standard in standard_state_names:
    matches.append(similar(state, standard))

  #Position of the maximum score in the list. We will use it to know what is the standard state name for every state.  
  maxpos = matches.index(max(matches))
  standard_names.append(standard_state_names[maxpos])


beds['State/UT'] = pd.DataFrame(standard_names)
beds
# Out:
#              State/UT  ...  Reference Period
# 0      Andhra Pradesh  ...        01.01.2017
# 1   Arunachal Pradesh  ...        31.12.2018
# 2               Assam  ...        31.12.2017
# 3               Bihar  ...        31.12.2018
# 4        Chhattisgarh  ...        01.01.2016
# 5                 Goa  ...        31.12.2018
# 6             Gujarat  ...        31.12.2018
# 7             Haryana  ...        31.12.2016
# 8    Himachal Pradesh  ...        31.12.2017
# 9     Jammu & Kashmir  ...        31.12.2018
# 10          Jharkhand  ...        31.12.2015
# 11          Karnataka  ...        31.12.2018
# 12             Kerala  ...        01.01.2017
# 13     Madhya Pradesh  ...        01.01.2018
# 14        Maharashtra  ...        31.12.2015
# 15            Manipur  ...        01.01.2014
# 16          Meghalaya  ...        31.12.2017
# 17            Mizoram  ...        31.12.2017
# 18           Nagaland  ...        31.12.2015
# 19             Odisha  ...        31.12.2018
# 20             Punjab  ...        31.12.2017
# 21          Rajasthan  ...        31.12.2018
# 22             Sikkim  ...        31.12.2017
# 23         Tamil Nadu  ...        31.12.2017
# 24          Telangana  ...        31.12.2017
# 25            Tripura  ...        31.12.2018
# 26      Uttar Pradesh  ...        31.12.2017
# 27        Uttarakhand  ...        31.12.2015
# 28        West Bengal  ...        01.01.2015
# 29      A.& N.Islands  ...        31.12.2016
# 30         Chandigarh  ...        31.12.2018
# 31       D.& N.Haveli  ...        31.12.2018
# 32        Daman & Diu  ...        31.12.2015
# 33              Delhi  ...        01.01.2015
# 34        Lakshadweep  ...        01.01.2016
# 35         Puducherry  ...        01.01.2016
#
# [36 rows x 8 columns]

# %% [markdown]
# Let's Merge the dataframes now

# %%
percapita_beds = pd.merge(beds, population, on ='State/UT',how='inner')
percapita_beds
# Out:
#              State/UT  ...  Population (2018)
# 0      Andhra Pradesh  ...         52,883,163
# 1   Arunachal Pradesh  ...          1,528,296
# 2               Assam  ...         34,586,234
# 3               Bihar  ...        119,461,013
# 4        Chhattisgarh  ...         28,566,990
# 5                 Goa  ...          1,542,750
# 6             Gujarat  ...         63,907,200
# 7             Haryana  ...         27,388,008
# 8    Himachal Pradesh  ...          7,316,708
# 9     Jammu & Kashmir  ...         13,635,010
# 10          Jharkhand  ...         37,329,128
# 11          Karnataka  ...         66,165,886
# 12             Kerala  ...         35,330,888
# 13     Madhya Pradesh  ...         82,342,793
# 14        Maharashtra  ...        120,837,347
# 15            Manipur  ...          3,008,546
# 16          Meghalaya  ...          3,276,323
# 17            Mizoram  ...          1,205,974
# 18           Nagaland  ...          2,189,297
# 19             Odisha  ...         45,429,399
# 20             Punjab  ...         29,611,935
# 21          Rajasthan  ...         78,230,816
# 22             Sikkim  ...            671,720
# 23         Tamil Nadu  ...         76,481,545
# 24          Telangana  ...         38,472,769
# 25            Tripura  ...          4,057,847
# 26      Uttar Pradesh  ...        228,959,599
# 27        Uttarakhand  ...         11,090,425
# 28        West Bengal  ...         97,694,960
# 29      A.& N.Islands  ...            419,978
# 30         Chandigarh  ...          1,126,705
# 31       D.& N.Haveli  ...            378,979
# 32        Daman & Diu  ...            220,084
# 33              Delhi  ...         18,345,784
# 34        Lakshadweep  ...             71,218
# 35         Puducherry  ...          1,375,592
#
# [36 rows x 9 columns]

# %% [markdown]
# # PERFECT MERGE!
